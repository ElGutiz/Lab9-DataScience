# %% [markdown]
# # PREDICCION DE PRECIOS DE AGUACATE EN EEUU

# %% [markdown]
# # Enunciado del Problema

# %% [markdown]
# - Los datos representan ventas semanales desde 2015 a 2018 a nivel de todos los EEUU.
# - Los datos provienen directamente de las cajas registradoras basados en ventas de aguacate variedad Hass.
# - El precio promedio de los aguacates reflejan el costo por unidad, aún cuando estos se vendan por bolsas.
# - Los códigos (Product Lookup codes ó PLU) en la tabla son solo de aguacates Hass.  No se incluyen otras variedades.
#
# Columnas relevantes en el conjunto de datos:
#
# - Date - la fecha de la observación
# - AveragePrice - el precio promedio de una unidad
# - type - convencional u orgánico
# - year - el año
# - Region - la ciudad o región de la observación
# - Total Volume - número total de aguacates vendidos
# - 4046 - número total de aguacates con PLU 4046 vendidos
# - 4225 - número total de aguacates con PLU 4225 vendidos
# - 4770 - número total de aguacates con PLU 4770 vendidos

# %% [markdown]
# # Importar las librerías

# %%
import numpy as np
import pandas as pd
import datetime
import matplotlib.pyplot as plt
from pandas.plotting import register_matplotlib_converters
import seaborn as sns
from prophet import *

# %% [markdown]
# # Carga de datos

# %%
df = pd.read_csv('./aguacates_EEUU.csv')

# %% [markdown]
# # Explorar el conjunto de datos

# %%
df.head()
# Out:
#    Unnamed: 0        Date  AveragePrice  Total Volume     4046       4225  \
# 0           0  2015-12-27          1.33      64236.62  1036.74   54454.85
# 1           1  2015-12-20          1.35      54876.98   674.28   44638.81
# 2           2  2015-12-13          0.93     118220.22   794.70  109149.67
# 3           3  2015-12-06          1.08      78992.15  1132.00   71976.41
# 4           4  2015-11-29          1.28      51039.60   941.48   43838.39
#
#      4770  Total Bags  Small Bags  Large Bags  XLarge Bags          type  \
# 0   48.16     8696.87     8603.62       93.25          0.0  conventional
# 1   58.33     9505.56     9408.07       97.49          0.0  conventional
# 2  130.50     8145.35     8042.21      103.14          0.0  conventional
# 3   72.58     5811.16     5677.40      133.76          0.0  conventional
# 4   75.78     6183.95     5986.26      197.69          0.0  conventional
#
#    year  region
# 0  2015  Albany
# 1  2015  Albany
# 2  2015  Albany
# 3  2015  Albany
# 4  2015  Albany

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18249 entries, 0 to 18248
# Data columns (total 14 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Unnamed: 0    18249 non-null  int64
#  1   Date          18249 non-null  object
#  2   AveragePrice  18249 non-null  float64
#  3   Total Volume  18249 non-null  float64
#  4   4046          18249 non-null  float64
#  5   4225          18249 non-null  float64
#  6   4770          18249 non-null  float64
#  7   Total Bags    18249 non-null  float64
#  8   Small Bags    18249 non-null  float64
#  9   Large Bags    18249 non-null  float64
#  10  XLarge Bags   18249 non-null  float64
#  11  type          18249 non-null  object
#  12  year          18249 non-null  int64
#  13  region        18249 non-null  object
# dtypes: float64(9), int64(2), object(3)
# memory usage: 1.9+ MB

# %% [markdown]
# # Asegurar que estén los datos en orden cronológico

# %%
# convert to date
df['Date'] = pd.to_datetime(df['Date'])

# %%
df.sort_values(by='Date')
# Out:
#        Unnamed: 0       Date  AveragePrice  Total Volume        4046  \
# 11569          51 2015-01-04          1.75      27365.89     9307.34
# 9593           51 2015-01-04          1.49      17723.17     1189.35
# 10009          51 2015-01-04          1.68       2896.72      161.68
# 1819           51 2015-01-04          1.52      54956.80     3013.04
# 9333           51 2015-01-04          1.64       1505.12        1.27
# ...           ...        ...           ...           ...         ...
# 8574            0 2018-03-25          1.36     908202.13   142681.06
# 9018            0 2018-03-25          0.70    9010588.32  3999735.71
# 18141           0 2018-03-25          1.42     163496.70    29253.30
# 17673           0 2018-03-25          1.70     190257.38    29644.09
# 8814            0 2018-03-25          1.34    1774776.77    63905.98
#
#             4225       4770  Total Bags  Small Bags  Large Bags  XLarge Bags  \
# 11569    3844.81     615.28    13598.46    13061.10      537.36         0.00
# 9593    15628.27       0.00      905.55      905.55        0.00         0.00
# 10009     206.96       0.00     2528.08     2528.08        0.00         0.00
# 1819    35456.88    1561.70    14925.18    11264.80     3660.38         0.00
# 9333     1129.50       0.00      374.35      186.67      187.68         0.00
# ...          ...        ...         ...         ...         ...          ...
# 8574   463136.28  174975.75   127409.04   103579.41    22467.04      1362.59
# 9018   966589.50   30130.82  4014132.29  3398569.92   546409.74     69152.63
# 18141    5080.04       0.00   129163.36   109052.26    20111.10         0.00
# 17673   70982.10       0.00    89631.19    89424.11      207.08         0.00
# 8814   908653.71     843.45   801373.63   774634.09    23833.93      2905.61
#
#                type  year              region
# 11569       organic  2015           Southeast
# 9593        organic  2015             Chicago
# 10009       organic  2015  HarrisburgScranton
# 1819   conventional  2015          Pittsburgh
# 9333        organic  2015               Boise
# ...             ...   ...                 ...
# 8574   conventional  2018             Chicago
# 9018   conventional  2018        SouthCentral
# 18141       organic  2018        SouthCentral
# 17673       organic  2018          California
# 8814   conventional  2018             NewYork
#
# [18249 rows x 14 columns]

# %% [markdown]
# # Realizar una gráfica de precios promedio vrs fecha
#
# ¿Cuál es la tendencia a nivel nacional?

# %%
df.plot(kind='scatter',x='Date',y='AveragePrice',color='red')
plt.xlabel('Fecha')
plt.ylabel('Precio Promedio')
plt.rcParams['figure.figsize'] = [20, 20]
plt.show()

# %% [markdown]
# La tendencia a nivel nacional es que exista un incremento del precio promedio a finales de año y esta disminuya a principios del siguiente.

# %% [markdown]
# # Realizar una gráfica de barras para ver el número de regiones

# %%
common_keywords=df["region"].value_counts().to_frame()
fig=plt.figure(figsize=(35,15))
sns.barplot(data=common_keywords,x=common_keywords.index,y="region",palette="viridis")
plt.title("Conteo de Regiones",size=16)
plt.xticks(rotation=70,size=12)
plt.xlabel('Region')
plt.ylabel('Conteo')
# Out:
# Text(0, 0.5, 'Conteo')

# %%
df["region"].value_counts()
# Out:
# Albany                 338
# Sacramento             338
# Northeast              338
# NorthernNewEngland     338
# Orlando                338
# Philadelphia           338
# PhoenixTucson          338
# Pittsburgh             338
# Plains                 338
# Portland               338
# RaleighGreensboro      338
# RichmondNorfolk        338
# Roanoke                338
# SanDiego               338
# Atlanta                338
# SanFrancisco           338
# Seattle                338
# SouthCarolina          338
# SouthCentral           338
# Southeast              338
# Spokane                338
# StLouis                338
# Syracuse               338
# Tampa                  338
# TotalUS                338
# West                   338
# NewYork                338
# NewOrleansMobile       338
# Nashville              338
# Midsouth               338
# BaltimoreWashington    338
# Boise                  338
# Boston                 338
# BuffaloRochester       338
# California             338
# Charlotte              338
# Chicago                338
# CincinnatiDayton       338
# Columbus               338
# DallasFtWorth          338
# Denver                 338
# Detroit                338
# GrandRapids            338
# GreatLakes             338
# HarrisburgScranton     338
# HartfordSpringfield    338
# Houston                338
# Indianapolis           338
# Jacksonville           338
# LasVegas               338
# LosAngeles             338
# Louisville             338
# MiamiFtLauderdale      338
# WestTexNewMexico       335
# Name: region, dtype: int64

# %% [markdown]
# # Realizar una gráfica de barras para ver de qué años se tiene información

# %%
df['Year'] = df['Date'].dt.year

common_keywords=df["Year"].value_counts().to_frame()
fig=plt.figure(figsize=(15,15))
sns.barplot(data=common_keywords,x=common_keywords.index,y="Year",palette="viridis")
plt.title("Conteo de Año",size=16)
plt.xticks(rotation=70,size=12)
plt.xlabel('Año')
plt.ylabel('Conteo')
# Out:
# Text(0, 0.5, 'Conteo')

# %%
df["Year"].value_counts()
# Out:
# 2017    5722
# 2016    5616
# 2015    5615
# 2018    1296
# Name: Year, dtype: int64

# %% [markdown]
# # Preparar los datos para que se acoplen a lo que requiere el modelo a utilizar

# %%
df_prepared = df[['Date', 'AveragePrice']].rename(columns={'Date': 'ds', 'AveragePrice': 'y'})
df_prepared.head()
# Out:
#           ds     y
# 0 2015-12-27  1.33
# 1 2015-12-20  1.35
# 2 2015-12-13  0.93
# 3 2015-12-06  1.08
# 4 2015-11-29  1.28

# %% [markdown]
# # Creación y ajuste del modelo

# %%
model = Prophet(interval_width = 0.95)
model.fit(df_prepared)
# Out:
# 23:58:36 - cmdstanpy - INFO - Chain [1] start processing
# 23:58:42 - cmdstanpy - INFO - Chain [1] done processing

# %% [markdown]
# # Realizar predicciones

# %%
predictions = model.make_future_dataframe(periods=365, freq='D')

# %%
predictions.tail()
# Out:
#             ds
# 529 2019-03-21
# 530 2019-03-22
# 531 2019-03-23
# 532 2019-03-24
# 533 2019-03-25

# %% [markdown]
# # Pronosticar hacia el futuro un año (365 días)

# %%
prediction = model.predict(predictions)

# %%
prediction
# Out:
#             ds     trend  yhat_lower  yhat_upper  trend_lower  trend_upper  \
# 0   2015-01-04  1.498666    0.649731    2.080815     1.498666     1.498666
# 1   2015-01-11  1.493474    0.673596    2.102310     1.493474     1.493474
# 2   2015-01-18  1.488283    0.609294    2.122901     1.488283     1.488283
# 3   2015-01-25  1.483091    0.636703    2.079371     1.483091     1.483091
# 4   2015-02-01  1.477900    0.567224    2.006158     1.477900     1.477900
# ..         ...       ...         ...         ...          ...          ...
# 529 2019-03-21  1.170176    0.293667    1.845443     0.836089     1.468491
# 530 2019-03-22  1.169461    0.300576    1.837421     0.833879     1.468982
# 531 2019-03-23  1.168747    0.268820    1.852314     0.831675     1.469456
# 532 2019-03-24  1.168033    0.234177    1.836015     0.829487     1.469929
# 533 2019-03-25  1.167319    0.310213    1.856245     0.827299     1.470403
#
#      additive_terms  additive_terms_lower  additive_terms_upper    yearly  \
# 0         -0.114560             -0.114560             -0.114560 -0.114560
# 1         -0.106156             -0.106156             -0.106156 -0.106156
# 2         -0.105883             -0.105883             -0.105883 -0.105883
# 3         -0.124901             -0.124901             -0.124901 -0.124901
# 4         -0.153304             -0.153304             -0.153304 -0.153304
# ..              ...                   ...                   ...       ...
# 529       -0.087160             -0.087160             -0.087160 -0.087160
# 530       -0.085454             -0.085454             -0.085454 -0.085454
# 531       -0.083473             -0.083473             -0.083473 -0.083473
# 532       -0.081237             -0.081237             -0.081237 -0.081237
# 533       -0.078773             -0.078773             -0.078773 -0.078773
#
#      yearly_lower  yearly_upper  multiplicative_terms  \
# 0       -0.114560     -0.114560                   0.0
# 1       -0.106156     -0.106156                   0.0
# 2       -0.105883     -0.105883                   0.0
# 3       -0.124901     -0.124901                   0.0
# 4       -0.153304     -0.153304                   0.0
# ..            ...           ...                   ...
# 529     -0.087160     -0.087160                   0.0
# 530     -0.085454     -0.085454                   0.0
# 531     -0.083473     -0.083473                   0.0
# 532     -0.081237     -0.081237                   0.0
# 533     -0.078773     -0.078773                   0.0
#
#      multiplicative_terms_lower  multiplicative_terms_upper      yhat
# 0                           0.0                         0.0  1.384106
# 1                           0.0                         0.0  1.387318
# 2                           0.0                         0.0  1.382400
# 3                           0.0                         0.0  1.358190
# 4                           0.0                         0.0  1.324596
# ..                          ...                         ...       ...
# 529                         0.0                         0.0  1.083015
# 530                         0.0                         0.0  1.084007
# 531                         0.0                         0.0  1.085274
# 532                         0.0                         0.0  1.086796
# 533                         0.0                         0.0  1.088547
#
# [534 rows x 16 columns]

# %% [markdown]
# # Graficar los datos históricos y los del futuro

# %%
mean_price = df[['Date', 'AveragePrice']].groupby('Date')['AveragePrice'].mean()

# %%
plt.rcParams['figure.figsize'] = [20, 20]
plt.plot(prediction['ds'], prediction['trend'], label = "Prediction")
plt.plot(mean_price.index, mean_price, label = "Historical")
plt.title("Datos Historicos vs Tendencia al Futuro",size=16)
plt.xticks(size=12)
plt.xlabel('Año-Mes')
plt.ylabel('Precio Promedio')
# Out:
# Text(0, 0.5, 'Precio Promedio')

# %% [markdown]
# # Graficar los componentes del pronóstico

# %%
model.plot_components(prediction)

# %% [markdown]
# Como se puede ver en la grafica que contiene los datos actuales vs los futuros datos, y los componentes de esta, se puede ver que existirá una disminucion del precio promedio en los siguientes meses. Y esto sigue la misma tendencia de los años anteriores, dado a que la prediccion es

# %% [markdown]
# # PARTE 2
#
# ### Repetir el ejercicio pero solo con la región oeste "West" de los EEUU

# %% [markdown]
# ### Leer el archivo de datos

# %%
df = pd.read_csv('aguacates_EEUU.csv')

# %%
df = df[df['region'] == 'West']
df
# Out:
#        Unnamed: 0        Date  AveragePrice  Total Volume        4046  \
# 2704            0  2015-12-27          0.83    5291979.63  2038443.68
# 2705            1  2015-12-20          0.88    4737649.03  2017331.24
# 2706            2  2015-12-13          0.85    4899439.92  1798995.46
# 2707            3  2015-12-06          0.75    6202513.84  2097720.52
# 2708            4  2015-11-29          0.99    3719603.21  1461861.54
# ...           ...         ...           ...           ...         ...
# 18232           7  2018-02-04          1.41     283378.47    22474.66
# 18233           8  2018-01-28          1.80     185974.53    22918.40
# 18234           9  2018-01-21          1.83     189317.99    27049.44
# 18235          10  2018-01-14          1.82     207999.67    33869.12
# 18236          11  2018-01-07          1.48     297190.60    34734.97
#
#              4225       4770  Total Bags  Small Bags  Large Bags  XLarge Bags  \
# 2704   1717599.45  125254.82  1410681.68   838267.79   567269.76      5144.13
# 2705   1314711.00  130849.60  1274757.19   843691.13   417746.45     13319.61
# 2706   1596329.01  134101.62  1370013.83   851506.76   517936.19       570.88
# 2707   2051392.83  107568.34  1945832.15  1360760.83   582846.33      2224.99
# 2708   1216811.00  104219.76   936710.91   688674.00   247318.15       718.76
# ...           ...        ...         ...         ...         ...          ...
# 18232    55360.49     133.41   205409.91    70232.59   134666.91       510.41
# 18233    33051.14      93.52   129911.47    77822.23    51986.86       102.38
# 18234    33561.32     439.47   128267.76    76091.99    51947.50       228.27
# 18235    47435.14     433.52   126261.89    89115.78    37133.99        12.12
# 18236    62967.74     157.77   199330.12   103761.55    95544.39        24.18
#
#                type  year region
# 2704   conventional  2015   West
# 2705   conventional  2015   West
# 2706   conventional  2015   West
# 2707   conventional  2015   West
# 2708   conventional  2015   West
# ...             ...   ...    ...
# 18232       organic  2018   West
# 18233       organic  2018   West
# 18234       organic  2018   West
# 18235       organic  2018   West
# 18236       organic  2018   West
#
# [338 rows x 14 columns]

# %% [markdown]
# ### Por si acaso no están ordenadas las observaciones

# %%
# convert to date
df['Date'] = pd.to_datetime(df['Date'])

# %%
df.sort_values(by='Date')
# Out:
#        Unnamed: 0       Date  AveragePrice  Total Volume        4046  \
# 2755           51 2015-01-04          0.89    5794410.58  2275446.87
# 11881          51 2015-01-04          1.40     187548.30    70313.71
# 2754           50 2015-01-11          0.95    5333097.71  2203111.92
# 11880          50 2015-01-11          1.39     223156.55    80139.16
# 2753           49 2015-01-18          0.96    5475363.01  2431736.63
# ...           ...        ...           ...           ...         ...
# 18227           2 2018-03-11          1.63     264691.87    27566.25
# 18226           1 2018-03-18          1.73     210067.47    33437.98
# 9103            1 2018-03-18          0.99    7254940.65  2099082.66
# 9102            0 2018-03-25          0.93    7667064.46  2567279.74
# 18225           0 2018-03-25          1.60     271723.08    26996.28
#
#              4225       4770  Total Bags  Small Bags  Large Bags  XLarge Bags  \
# 2755   2582300.65   97024.09   839638.97   688813.01   150819.57         6.39
# 11881    72942.11      24.30    44268.18    10023.72    34244.46         0.00
# 2754   2292761.26  127412.09   709812.44   598705.08   111073.82        33.54
# 11880   111395.01      63.88    31558.50     9296.76    22261.74         0.00
# 2753   2258069.63   76348.13   709208.62   527358.78   181809.88        39.96
# ...           ...        ...         ...         ...         ...          ...
# 18227    60383.57     276.42   176465.63   107174.93    69290.70         0.00
# 18226    47165.54     110.40   129353.55    73163.12    56020.24       170.19
# 9103   1707752.84  115997.93  3332107.22  1333247.05  1982086.02     16774.15
# 9102   1912986.38  118289.91  3068508.43  1309580.19  1745630.06     13298.18
# 18225    77861.39     117.56   166747.85    87108.00    79495.39       144.46
#
#                type  year region
# 2755   conventional  2015   West
# 11881       organic  2015   West
# 2754   conventional  2015   West
# 11880       organic  2015   West
# 2753   conventional  2015   West
# ...             ...   ...    ...
# 18227       organic  2018   West
# 18226       organic  2018   West
# 9103   conventional  2018   West
# 9102   conventional  2018   West
# 18225       organic  2018   West
#
# [338 rows x 14 columns]

# %% [markdown]
# # Graficar el precio promedio vs fecha
#
# ### ¿Es diferente la tendencia comparado a la tendencia nacional?

# %%
df.plot(kind='scatter',x='Date',y='AveragePrice',color='red')
plt.xlabel('Fecha')
plt.ylabel('Precio Promedio')
plt.rcParams['figure.figsize'] = [20, 20]
plt.show()

# %% [markdown]
# Se puede apreciar que sigue la misma tendencia a comparacion de a la de nivel nacional, la cual es que aumente a finales del año y empiece a disminuir a principios del siguiente.

# %% [markdown]
# # Crear el modelo y ajustarlo con los datos

# %% [markdown]
# ### Preparar los datos para que sean aceptados por el modelo a usar

# %%
df_prepared = df[['Date', 'AveragePrice']].rename(columns={'Date': 'ds', 'AveragePrice': 'y'})
df_prepared.head()
# Out:
#              ds     y
# 2704 2015-12-27  0.83
# 2705 2015-12-20  0.88
# 2706 2015-12-13  0.85
# 2707 2015-12-06  0.75
# 2708 2015-11-29  0.99

# %%
model = Prophet(interval_width = 0.95)
model.fit(df_prepared)
# Out:
# 23:58:45 - cmdstanpy - INFO - Chain [1] start processing
# 23:58:46 - cmdstanpy - INFO - Chain [1] done processing

# %% [markdown]
# # Pronosticar al futuro un año (365 días)

# %%
prediction = model.predict(predictions)
prediction
# Out:
#             ds     trend  yhat_lower  yhat_upper  trend_lower  trend_upper  \
# 0   2015-01-04  1.244817    0.382657    1.728014     1.244817     1.244817
# 1   2015-01-11  1.243974    0.414956    1.750666     1.243974     1.243974
# 2   2015-01-18  1.243131    0.454912    1.730483     1.243131     1.243131
# 3   2015-01-25  1.242288    0.398369    1.737533     1.242288     1.242288
# 4   2015-02-01  1.241444    0.466193    1.739146     1.241444     1.241444
# ..         ...       ...         ...         ...          ...          ...
# 529 2019-03-21  1.735840    0.876822    2.228445     1.687318     1.782873
# 530 2019-03-22  1.736418    0.922322    2.201186     1.687760     1.783629
# 531 2019-03-23  1.736996    0.901404    2.199434     1.688202     1.784386
# 532 2019-03-24  1.737574    0.933249    2.188728     1.688644     1.785142
# 533 2019-03-25  1.738152    0.921154    2.194083     1.689086     1.785955
#
#      additive_terms  additive_terms_lower  additive_terms_upper    yearly  \
# 0         -0.184886             -0.184886             -0.184886 -0.184886
# 1         -0.165295             -0.165295             -0.165295 -0.165295
# 2         -0.156108             -0.156108             -0.156108 -0.156108
# 3         -0.168794             -0.168794             -0.168794 -0.168794
# 4         -0.191185             -0.191185             -0.191185 -0.191185
# ..              ...                   ...                   ...       ...
# 529       -0.204383             -0.204383             -0.204383 -0.204383
# 530       -0.199298             -0.199298             -0.199298 -0.199298
# 531       -0.193648             -0.193648             -0.193648 -0.193648
# 532       -0.187537             -0.187537             -0.187537 -0.187537
# 533       -0.181082             -0.181082             -0.181082 -0.181082
#
#      yearly_lower  yearly_upper  multiplicative_terms  \
# 0       -0.184886     -0.184886                   0.0
# 1       -0.165295     -0.165295                   0.0
# 2       -0.156108     -0.156108                   0.0
# 3       -0.168794     -0.168794                   0.0
# 4       -0.191185     -0.191185                   0.0
# ..            ...           ...                   ...
# 529     -0.204383     -0.204383                   0.0
# 530     -0.199298     -0.199298                   0.0
# 531     -0.193648     -0.193648                   0.0
# 532     -0.187537     -0.187537                   0.0
# 533     -0.181082     -0.181082                   0.0
#
#      multiplicative_terms_lower  multiplicative_terms_upper      yhat
# 0                           0.0                         0.0  1.059931
# 1                           0.0                         0.0  1.078679
# 2                           0.0                         0.0  1.087023
# 3                           0.0                         0.0  1.073494
# 4                           0.0                         0.0  1.050260
# ..                          ...                         ...       ...
# 529                         0.0                         0.0  1.531458
# 530                         0.0                         0.0  1.537120
# 531                         0.0                         0.0  1.543349
# 532                         0.0                         0.0  1.550038
# 533                         0.0                         0.0  1.557071
#
# [534 rows x 16 columns]

# %% [markdown]
# # Graficar datos históricos y pronosticados

# %%
mean_price = df[['Date', 'AveragePrice']].groupby('Date')['AveragePrice'].mean()

# %%
plt.rcParams['figure.figsize'] = [20, 20]
plt.plot(prediction['ds'], prediction['trend'], label = "Prediction")
plt.plot(mean_price.index, mean_price, label = "Historical")
plt.title("Datos Historicos vs Tendencia al Futuro",size=16)
plt.xticks(size=12)
plt.xlabel('Año-Mes')
plt.ylabel('Precio Promedio')
# Out:
# Text(0, 0.5, 'Precio Promedio')

# %%
model.plot_components(prediction)

# %% [markdown]
# A pesar de que sigue la misma tendencia a nivel nacional, se predice que aumentará en los proximos meses a principios del siguiente año. Esto pareciera que no sigue la misma tendencia a futuro a nivel nacional como en el analisis anterior.
